# %%
from datetime import datetime
import pandas
# Out:
# /home/gram/.local/lib/python3.9/site-packages/pandas/compat/__init__.py:97: UserWarning: Could not import the lzma module. Your installed Python is incomplete. Attempting to use lzma compression will result in a RuntimeError.
#   warnings.warn(msg)

# %%
df = pandas.read_json('./pythonetc.ndjson', lines=True)
df.head()
# Out:
#     id                      date  \
# 0  684 2021-12-13 19:24:09+00:00
# 1  682 2021-12-13 19:24:05+00:00
# 2  681 2021-12-13 19:23:59+00:00
# 3  680 2021-12-13 19:23:54+00:00
# 4  679 2021-12-13 19:23:49+00:00
#
#                                                 text  views  forwards  \
# 0                                                      3278        10
# 1  Finally, you can express your gratitude toward...   3288         2
# 2                                                      3303         3
# 3  You are also welcome to consider joining my te...   3278         2
# 4  Hi there! As you’ve probably already noticed t...   3235         3
#
#          buttons
# 0  {'Donate': 0}
# 1             {}
# 2             {}
# 3             {}
# 4             {}

# %%
df['likes'] = df.buttons.apply(lambda x: x.get('👍', 0))
df['dislikes'] = df.buttons.apply(lambda x: x.get('👎', 0))

# %%
YEAR = datetime.now().year

# %% [markdown]
# Filter posts published in this year, filter out posts without text, and sort the result by forwards count.

# %%
df[(df.date.dt.year == YEAR) & (df.text != "")].sort_values(by='forwards', ascending=False)[:10]
# Out:
#      id                      date  \
# 35  646 2021-01-27 16:01:01+00:00
# 7   676 2021-08-26 15:00:16+00:00
# 29  652 2021-03-11 15:00:10+00:00
# 31  650 2021-03-04 15:00:15+00:00
# 23  658 2021-04-01 15:00:08+00:00
# 25  656 2021-03-25 15:00:07+00:00
# 28  653 2021-03-16 15:01:07+00:00
# 19  662 2021-04-20 15:01:07+00:00
# 16  666 2021-04-29 15:00:06+00:00
# 17  665 2021-04-27 15:00:41+00:00
#
#                                                  text  views  forwards  \
# 35  Today Guido van Rossum posted a Python riddle:...   6740       111
# 7   Python 3.7 introduced Development Mode. The mo...   7119        53
# 29  Suppose, you have 10 lists:\n\nlists = [list(r...   5530        50
# 31  Let's learn a bit more about strings performan...   5205        44
# 23  In most of the programming languages (like C, ...   4938        36
# 25  PEP-589 (landed in Python 3.8) introduced typi...   5063        34
# 28  Starting Python 3.8, the interpreter warns abo...   4503        33
# ...
